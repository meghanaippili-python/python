# %%
! pip install pandas
! pip install numpy
! pip install matplotlib
! pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# LOAD THE DATA

# %%
data = pd.read_csv('/content/netflix_movies (1).csv')

# %%
# HEAD : top of the data .

# %%
data.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# TAIL: shows the bottom of the data

# %%
data.tail(5)
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
data.shape
# Out:
# (8807, 12)

# %%
data.shape[0]
# Out:
# 8807

# %%
data.shape[1]
# Out:
# 12

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
data.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
# CHECKING NULL VALUES

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
# fill the missing null values

# %%
data['director'].fillna(data['director'].mode()[0],inplace=True)
data['cast'].fillna(data['cast'].mode()[0],inplace=True)
data['country'].fillna(data['country'].mode()[0],inplace=True)
data['date_added'].fillna(data['date_added'].mode()[0],inplace=True)
data['rating'].fillna(data['rating'].mode()[0],inplace=True)
data['duration'].fillna(data['duration'].mode()[0],inplace=True)
# Out:
# <ipython-input-20-b119d98545c0>:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['duration'].fillna(data['duration'].mode()[0],inplace=True)

# %%
data.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
# VISUALIZATION PROCESS

# %%
# Basicplots

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water    Rajiv Chilaka
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans    Rajiv Chilaka
# 4      s5  TV Show           Kota Factory    Rajiv Chilaka
#
#                                                 cast        country  \
# 0                                 David Attenborough  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 3                                 David Attenborough  United States
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
#lineplot

# %%
sns.lineplot(data=data,x='release_year',y='duration')
plt.title('this is a LINEPLOT')
plt.show()

# %%
# Barplot

# %%
sns.barplot(data=data,x='release_year',y='duration')
plt.title('this is a BARPLOT')
plt.show()

# %%
# scatter plot

# %%
sns.scatterplot(data=data,x='release_year',y='duration')
plt.title('this is a SCATTERPLOT')
plt.show()

# %%
# hue

# %%
sns.scatterplot(data=data,x='release_year',y='duration',hue='rating')
plt.title('this is a SCATTERPLOT')
plt.show()

# %%
# UNIVARIATE

# %%
# Histogram

# %%
sns.histplot(data['release_year'])
plt.title('this is a HISTOGRAM')
plt.show()

# %%
#boxplot

# %%
sns.boxplot(data['release_year'])
plt.title('this is a BOXPLOT')
plt.show()

# %%
#violoinplot

# %%
sns.violinplot(data['release_year'])
plt.title('this is a VIOLINPLOT')
plt.show()

# %%
#countplot

# %%
sns.countplot(data['release_year'])
plt.title('this is a COUNTPLOT')
plt.show()

# %%
#kdeplot

# %%
sns.kdeplot(data['release_year'])
plt.title('this is a KDEPLOT')
plt.show()

# %%
# bivariate

# %%
#scatterplot

# %%
sns.scatterplot(data=data,x='release_year',y='duration')
plt.title('this is a SCATTERPLOT')
plt.show()

# %%
#boxplot

# %%
sns.boxplot(data=data,x='release_year',y='duration')
plt.title('this is a BOXPLOT')
plt.show()

# %%
# Multivariate

# %%
#pairplot

# %%
sns.pairplot(data)
plt.title('this is a PAIRPLOT')
plt.show()

# %%
# jointplot

# %%
sns.jointplot(data=data,x='release_year',y='duration')
plt.title('this is a JOINTPLOT')
plt.show()

# %%
#QUESTIONS

# %%
#Q1.Find out which types of genre has most movies and TV Shows?

# %%
sns.countplot(data['listed_in'])
plt.title('this is a COUNTPLOT')
plt.show()

# %%
#Q2. What is the distribution of content types (e.g., Movies vs. TV Shows) in the dataset?

# %%
sns.countplot(data['type'])
plt.title('this is a COUNTPLOT')
plt.show()

# %%
#Q3.Which countries contribute the most to the content library?

# %%
sns.countplot(data['country'])
plt.title('this is a COUNTPLOT')
plt.show()

# %%
# Q4. What is the average duration of movies, and how does it vary across different ratings?

# %%
sns.barplot(data=data,x='rating',y='duration')
plt.title('this is a BARPLOT')
plt.show()

# %%
#Q5.What are the most common ratings, and how are they distributed across different types of content?

# %%
sns.countplot(data['rating'])
plt.title('this is a COUNTPLOT')
plt.show()
